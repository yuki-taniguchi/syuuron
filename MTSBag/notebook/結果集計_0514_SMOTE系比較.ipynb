# %% [markdown]
# # 分析結果を集計するノートブック
# - 一旦AUCだけで比較してみる
# - output/ファイルから各手法の各データの結果をまとめる
# - それらの平均をまとめる
# - 分散分析とかグラフとかにして表示する

# %%
from glob import glob

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
ex_name = '0514'

# %%
file_list = glob(f'../data/output/{ex_name}*')

# %%
e_index = ['AUC', 'accuracy', 'recall', 'Specificity', 'precision', 'gmeans', 'RS']

method = list(set([file.split('\\')[1].split('_')[1] for file in file_list]))
method = list(set(method)- set(e_index))
method = ['SMOTEMTSBag',
    # 'WMTS',
    # 'MTGS',
    'MTS',
    'MTS2',
    # 'WMTGS',
    'MTSBagImpAgg',
    'SMOTEMTSBagImpAgg',
    'MTSBag']

# %%
data = list(set([file.split('\\')[1].split('_')[2] for file in file_list]))
data = ['car', 'cancer', 'letter', 'wine', 'abalone',
#  'yeast'
 ]
data
# Out:
# ['car', 'cancer', 'letter', 'wine', 'abalone']

# %%
e_index = ['AUC', 'accuracy', 'recall', 'Specificity', 'precision', 'gmeans', 'RS']
multi_columns = [
    np.array(
        [method[0]] * 2 + 
        [method[1]] * 2 + 
        [method[2]] * 2 + 
        [method[3]] * 2 
        +
        [method[4]] * 2 +
        [method[5]] * 2 
        # +
        # [method[6]] * 2 
        # +
        # [method[7]] * 2 +
        # [method[8]] * 2 
        ),
    np.array(["mean", "std"] * len(method))
]

# %%
for e in e_index:
    index_result_df = pd.DataFrame(
                index=data,
                columns=multi_columns,
                )
    for m in method:
        for d in data:     
            df = pd.read_csv(f'../data/output/{ex_name}_{m}_{d}_result.csv', index_col=0)
            index_result_df.loc[d, m] = [df[e].mean(), df[e].std()]
    index_result_df.loc['whole_mean'] = index_result_df.mean(axis=0)
    print(e)
    display(index_result_df)
    index_result_df.to_csv(f'../data/output/{ex_name}_{e}_score.csv')
    a = index_result_df.T[index_result_df.T.index.get_level_values(1) == 'mean']
    a = a.reset_index(level=1).drop('level_1', axis=1)
    sns.heatmap(a.T.astype(float), annot=True, fmt='.4', cmap='coolwarm', vmin=0.9000, vmax=1.0000)
    plt.show()
# Out:
# AUC
#            SMOTEMTSBag                 MTS                MTS2            \
#                   mean       std      mean       std      mean       std
# car           0.971067  0.009304  0.973099  0.008034  0.974324  0.005617
# cancer        0.977442  0.013745  0.946351  0.062023  0.948798  0.033729
# letter        0.950936  0.011558  0.918355  0.033662  0.923235  0.030644
# wine          0.997286  0.004494  0.992137  0.010902   0.99876  0.002015
# abalone       0.971261  0.017842  0.986174   0.00169  0.983452  0.006195
# whole_mean    0.973598  0.011389  0.963223  0.023262  0.965714   0.01564
#
#            MTSBagImpAgg           SMOTEMTSBagImpAgg              MTSBag  \
#                    mean       std              mean       std      mean
# car            0.981977  0.012011          0.972837  0.008656  0.975745
# cancer         0.985934  0.006054           0.97788   0.01229  0.987332
# letter         0.973235  0.008335          0.974394  0.011288  0.924265
# wine           0.995494  0.005927          0.997706  0.004194  0.995605
# abalone        0.986433  0.005242          0.986841  0.003763  0.953121
# whole_mean     0.984615  0.007514          0.981932  0.008038  0.967213
#
#
#                  std
# car         0.008677
# cancer      0.007582
# letter      0.014372
# wine        0.006846
# abalone     0.044746
# whole_mean  0.016445
# accuracy
#            SMOTEMTSBag                 MTS                MTS2            \
#                   mean       std      mean       std      mean       std
# car           0.937283  0.022637   0.95289  0.008293  0.952601   0.00761
# cancer        0.936429  0.024846  0.912857  0.066904  0.923571  0.023096
# letter         0.96265  0.008652  0.966825  0.009714  0.966975  0.009853
# wine          0.966667  0.036571  0.941667  0.044309  0.944444  0.045361
# abalone       0.950478  0.005838   0.97488  0.004066  0.973445  0.006924
# whole_mean    0.950701  0.019709  0.949824  0.026657  0.952207  0.018569
#
#            MTSBagImpAgg           SMOTEMTSBagImpAgg              MTSBag  \
#                    mean       std              mean       std      mean
# car            0.956358  0.009483          0.943931  0.010571  0.950867
# cancer         0.956429    0.0128          0.937857  0.024058  0.954286
# letter           0.9838  0.002044            0.9661  0.012112    0.9843
# wine           0.966667  0.034146          0.969444  0.024322  0.963889
# abalone        0.975598  0.003791          0.952512   0.00623  0.979665
# whole_mean      0.96777  0.012453          0.953969  0.015459  0.966601
#
#
#                  std
# car         0.008617
# cancer      0.015865
# letter      0.002723
# wine        0.026352
# abalone      0.00465
# whole_mean  0.011641
# recall
#            SMOTEMTSBag                 MTS                MTS2            \
#                   mean       std      mean       std      mean       std
# car           0.841832  0.182759  0.921968  0.103506      0.95  0.106219
# cancer        0.984242  0.030251  0.916261  0.061407  0.909847  0.059636
# letter        0.838034  0.020119  0.568099  0.039406  0.566461   0.04928
# wine          0.944242  0.102715  0.928052  0.141489  0.877244  0.127079
# abalone       0.972616  0.035629  0.853328  0.078024  0.715586  0.114989
# whole_mean    0.916193  0.074295  0.837542  0.084766  0.803827  0.091441
#
#            MTSBagImpAgg           SMOTEMTSBagImpAgg              MTSBag  \
#                    mean       std              mean       std      mean
# car            0.982353  0.055805          0.903903  0.088142  0.943651
# cancer         0.973155  0.027439           0.98021  0.036238  0.979658
# letter         0.667662  0.054739          0.837576  0.057029  0.669084
# wine           0.943409  0.084567          0.972576  0.044332  0.970833
# abalone        0.850819  0.084798            0.9603  0.044421  0.865973
# whole_mean      0.88348   0.06147          0.930913  0.054033   0.88584
#
#
#                  std
# car          0.09788
# cancer       0.03349
# letter      0.065763
# wine        0.048947
# abalone     0.123373
# whole_mean  0.073891
# Specificity
#            SMOTEMTSBag                 MTS                MTS2            \
#                   mean       std      mean       std      mean       std
# car           0.941031  0.026047  0.954028   0.00943  0.952871  0.010223
# cancer         0.91039  0.038368  0.909907  0.081054  0.930349   0.03366
# letter        0.967714  0.009072  0.982714  0.009894  0.984108  0.010009
# wine          0.973543  0.025354  0.948938  0.057259  0.982143  0.045332
# abalone       0.950168   0.00597   0.97722  0.005075  0.978198  0.007714
# whole_mean    0.948569  0.020962  0.954561  0.032542  0.965534  0.021387
#
#            MTSBagImpAgg           SMOTEMTSBagImpAgg              MTSBag  \
#                    mean       std              mean       std      mean
# car            0.955316  0.011312           0.94562  0.013301  0.951604
# cancer          0.94849  0.014285          0.916117  0.039346  0.940884
# letter         0.996748  0.001943          0.971311   0.01427    0.9967
# wine           0.972998  0.026063          0.969302  0.034461  0.961504
# abalone        0.977718  0.004238          0.952401   0.00682  0.981312
# whole_mean     0.970254  0.011568           0.95095  0.021639  0.966401
#
#
#                  std
# car         0.008953
# cancer      0.030145
# letter      0.000933
# wine        0.040596
# abalone     0.004548
# whole_mean  0.017035
# precision
#            SMOTEMTSBag                 MTS                MTS2            \
#                   mean       std      mean       std      mean       std
# car           0.369134  0.074066  0.444819  0.103713  0.443559  0.089238
# cancer        0.854506  0.044906  0.848417  0.105601  0.878772   0.04979
# letter        0.521589  0.069883  0.598192  0.149667  0.636527  0.170258
# wine          0.925868  0.071249  0.840606  0.174109  0.955556  0.107344
# abalone        0.24009  0.045181    0.4145  0.062624  0.387201  0.089935
# whole_mean    0.582237  0.061057  0.629307  0.119143  0.660323  0.101313
#
#            MTSBagImpAgg           SMOTEMTSBagImpAgg              MTSBag  \
#                    mean       std              mean       std      mean
# car            0.496448  0.071259          0.435323  0.093148  0.437885
# cancer         0.905062  0.027487          0.857559  0.064824  0.900294
# letter         0.897575  0.053323          0.561998  0.076141  0.888112
# wine           0.929916  0.067577          0.927639  0.079156  0.915023
# abalone        0.403859  0.085603          0.235646  0.067653  0.402149
# whole_mean     0.726572   0.06105          0.603633  0.076184  0.708693
#
#
#                  std
# car         0.071538
# cancer      0.045701
# letter      0.031176
# wine        0.084797
# abalone     0.076598
# whole_mean  0.061962
# gmeans
#            SMOTEMTSBag                 MTS                MTS2            \
#                   mean       std      mean       std      mean       std
# car           0.883631  0.100571  0.936423  0.052749  0.949818  0.053557
# cancer        0.946257  0.023342  0.912464  0.063821  0.919255  0.028132
# letter        0.900468  0.010917  0.746774  0.026296  0.746003  0.033753
# wine          0.957464  0.058885  0.934191  0.071804  0.925035  0.064096
# abalone       0.961171  0.017619  0.912221  0.040672  0.833959  0.067446
# whole_mean    0.929798  0.042267  0.888415  0.051068  0.874814  0.049397
#
#            MTSBagImpAgg           SMOTEMTSBagImpAgg              MTSBag  \
#                    mean       std              mean       std      mean
# car            0.968263  0.026207          0.923302  0.041809  0.946304
# cancer         0.960624  0.014931          0.947117  0.020589  0.959706
# letter         0.815143  0.033134          0.901322  0.025923   0.81571
# wine           0.957338  0.051453          0.970445  0.023528  0.965483
# abalone        0.911007  0.045052          0.956049  0.019659  0.919631
# whole_mean     0.922475  0.034156          0.939647  0.026302  0.921367
#
#
#                  std
# car         0.049857
# cancer      0.015725
# letter      0.040882
# wine        0.025068
# abalone     0.066591
# whole_mean  0.039625
# RS
#            SMOTEMTSBag                 MTS                MTS2            \
#                   mean       std      mean       std      mean       std
# car           0.897791  0.205755  0.966687  0.111116  0.997619   0.11599
# cancer        1.083123  0.061477  1.011886  0.082217  0.979994  0.085784
# letter         0.86609  0.023423  0.578129  0.040111  0.575571  0.049261
# wine          0.969898  0.103564   0.98531  0.182802  0.897614  0.156473
# abalone       1.023683  0.038665  0.873506  0.082955  0.731994  0.120431
# whole_mean    0.968117  0.086577  0.883104   0.09984  0.836558  0.105588
#
#            MTSBagImpAgg           SMOTEMTSBagImpAgg              MTSBag  \
#                    mean       std              mean       std      mean
# car            1.028764  0.064842          0.956819  0.102058  0.992003
# cancer          1.02625  0.034036          1.072458  0.072752  1.042705
# letter         0.669886  0.055497          0.863095  0.069674  0.671288
# wine            0.96923  0.078565          1.005072  0.067908  1.012185
# abalone        0.870329   0.08818          1.008575  0.052484  0.882564
# whole_mean     0.912892  0.064224          0.981204  0.072975  0.920149
#
#
#                  std
# car         0.106188
# cancer      0.059328
# letter      0.065824
# wine        0.079492
# abalone     0.126386
# whole_mean  0.087443
