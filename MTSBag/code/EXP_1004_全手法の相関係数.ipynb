# %% [markdown]
# # 全手法の相関係数の推移を重ねる

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
_WMTS_time_series_corr_df_dict = np.load('+WMTS_time_series_corr_df_dict.npy', allow_pickle='TRUE')
WMTS_time_series_corr_df_dict = np.load('WMTS_time_series_corr_df_dict.npy', allow_pickle='TRUE')
MTS_time_series_corr_df_dict = np.load('MTS_time_series_corr_df_dict.npy', allow_pickle='TRUE')
MD_time_series_corr_df_dict = np.load('MD_time_series_corr_df_dict.npy', allow_pickle='TRUE')

# %%
# users = keio_df['UserID'].unique()
users = [
    # 1504, 
    1505, 
    1755, 
    1781, 
    1774, 
    1773
]
# user_id = users[0]

# %%
for user_id in users:
    print(user_id)
    plt.plot(_WMTS_time_series_corr_df_dict.item()[user_id])
    plt.plot(WMTS_time_series_corr_df_dict.item()[user_id])
    plt.plot(MTS_time_series_corr_df_dict.item()[user_id])
    plt.plot(MD_time_series_corr_df_dict.item()[user_id])
    plt.legend(['+WMTS', 'WMTS', 'MTS', 'MD'])
    plt.ylim(-1,1)
    plt.show()
# Out:
# 1505
# 1755
# 1781
# 1774
# 1773

# %%
for user_id in users:
    print(user_id)
    plt.plot(_WMTS_time_series_corr_df_dict.item()[user_id])
    plt.plot(WMTS_time_series_corr_df_dict.item()[user_id])
    plt.plot(MTS_time_series_corr_df_dict.item()[user_id])
    plt.plot(MD_time_series_corr_df_dict.item()[user_id])
    plt.legend(['+WMTS', 'WMTS', 'MTS', 'MD'])
    # plt.ylim(-1,1)
    plt.show()
# Out:
# 1505
# 1755
# 1781
# 1774
# 1773
