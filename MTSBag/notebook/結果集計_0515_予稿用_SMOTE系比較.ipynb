# %% [markdown]
# # 分析結果を集計するノートブック
# - 一旦AUCだけで比較してみる
# - output/ファイルから各手法の各データの結果をまとめる
# - それらの平均をまとめる
# - 分散分析とかグラフとかにして表示する

# %%
from glob import glob

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
ex_name = '0514'

# %%
file_list = glob(f'../data/output/{ex_name}*')

# %%
e_index = ['AUC', 'accuracy', 'recall', 'Specificity', 'precision', 'gmeans', 'RS']

method = list(set([file.split('\\')[1].split('_')[1] for file in file_list]))
method = list(set(method)- set(e_index))
method = ['MTSBag', 'SMOTEMTSBag', 'MTSBagImpAgg', 'SMOTEMTSBagImpAgg']
method
# Out:
# ['MTSBag', 'SMOTEMTSBag', 'MTSBagImpAgg', 'SMOTEMTSBagImpAgg']

# %%
data = list(set([file.split('\\')[1].split('_')[2] for file in file_list]))
data = ['car', 'cancer', 'letter', 'wine', 'abalone',
#  'yeast'
 ]
data
# Out:
# ['car', 'cancer', 'letter', 'wine', 'abalone']

# %%
e_index = ['AUC', 'accuracy', 'recall', 'Specificity', 'precision', 'gmeans', 'RS']
multi_columns = [
    np.array(
        [method[0]] * 2 + 
        [method[1]] * 2 + 
        [method[2]] * 2 + 
        [method[3]] * 2 
        # +
        # [method[4]] * 2 +
        # [method[5]] * 2 
        # +
        # [method[6]] * 2 
        # +
        # [method[7]] * 2 +
        # [method[8]] * 2 
        ),
    np.array(["mean", "std"] * len(method))
]

# %%
for e in e_index:
    index_result_df = pd.DataFrame(
                index=data,
                columns=multi_columns,
                )
    for m in method:
        for d in data:     
            df = pd.read_csv(f'../data/output/{ex_name}_{m}_{d}_result.csv', index_col=0)
            index_result_df.loc[d, m] = [df[e].mean(), df[e].std()]
    index_result_df.loc['whole_mean'] = index_result_df.mean(axis=0)
    print(e)
    display(index_result_df)
    index_result_df.to_csv(f'../data/output/{ex_name}_{e}_score.csv')
    a = index_result_df.T[index_result_df.T.index.get_level_values(1) == 'mean']
    a = a.reset_index(level=1).drop('level_1', axis=1)
    a.T.to_csv(f'../data/output/{ex_name}_{e}_score_mean.csv')
    sns.heatmap(a.T.astype(float), annot=True, fmt='.4', cmap='coolwarm', vmin=0.9000, vmax=1.0000)
    plt.show()
# Out:
# AUC
#               MTSBag           SMOTEMTSBag           MTSBagImpAgg            \
#                 mean       std        mean       std         mean       std
# car         0.975745  0.008677    0.971067  0.009304     0.981977  0.012011
# cancer      0.987332  0.007582    0.977442  0.013745     0.985934  0.006054
# letter      0.924265  0.014372    0.950936  0.011558     0.973235  0.008335
# wine        0.995605  0.006846    0.997286  0.004494     0.995494  0.005927
# abalone     0.953121  0.044746    0.971261  0.017842     0.986433  0.005242
# whole_mean  0.967213  0.016445    0.973598  0.011389     0.984615  0.007514
#
#            SMOTEMTSBagImpAgg
#                         mean       std
# car                 0.972837  0.008656
# cancer               0.97788   0.01229
# letter              0.974394  0.011288
# wine                0.997706  0.004194
# abalone             0.986841  0.003763
# whole_mean          0.981932  0.008038
# accuracy
#               MTSBag           SMOTEMTSBag           MTSBagImpAgg            \
#                 mean       std        mean       std         mean       std
# car         0.950867  0.008617    0.937283  0.022637     0.956358  0.009483
# cancer      0.954286  0.015865    0.936429  0.024846     0.956429    0.0128
# letter        0.9843  0.002723     0.96265  0.008652       0.9838  0.002044
# wine        0.963889  0.026352    0.966667  0.036571     0.966667  0.034146
# abalone     0.979665   0.00465    0.950478  0.005838     0.975598  0.003791
# whole_mean  0.966601  0.011641    0.950701  0.019709      0.96777  0.012453
#
#            SMOTEMTSBagImpAgg
#                         mean       std
# car                 0.943931  0.010571
# cancer              0.937857  0.024058
# letter                0.9661  0.012112
# wine                0.969444  0.024322
# abalone             0.952512   0.00623
# whole_mean          0.953969  0.015459
# recall
#               MTSBag           SMOTEMTSBag           MTSBagImpAgg            \
#                 mean       std        mean       std         mean       std
# car         0.943651   0.09788    0.841832  0.182759     0.982353  0.055805
# cancer      0.979658   0.03349    0.984242  0.030251     0.973155  0.027439
# letter      0.669084  0.065763    0.838034  0.020119     0.667662  0.054739
# wine        0.970833  0.048947    0.944242  0.102715     0.943409  0.084567
# abalone     0.865973  0.123373    0.972616  0.035629     0.850819  0.084798
# whole_mean   0.88584  0.073891    0.916193  0.074295      0.88348   0.06147
#
#            SMOTEMTSBagImpAgg
#                         mean       std
# car                 0.903903  0.088142
# cancer               0.98021  0.036238
# letter              0.837576  0.057029
# wine                0.972576  0.044332
# abalone               0.9603  0.044421
# whole_mean          0.930913  0.054033
# Specificity
#               MTSBag           SMOTEMTSBag           MTSBagImpAgg            \
#                 mean       std        mean       std         mean       std
# car         0.951604  0.008953    0.941031  0.026047     0.955316  0.011312
# cancer      0.940884  0.030145     0.91039  0.038368      0.94849  0.014285
# letter        0.9967  0.000933    0.967714  0.009072     0.996748  0.001943
# wine        0.961504  0.040596    0.973543  0.025354     0.972998  0.026063
# abalone     0.981312  0.004548    0.950168   0.00597     0.977718  0.004238
# whole_mean  0.966401  0.017035    0.948569  0.020962     0.970254  0.011568
#
#            SMOTEMTSBagImpAgg
#                         mean       std
# car                  0.94562  0.013301
# cancer              0.916117  0.039346
# letter              0.971311   0.01427
# wine                0.969302  0.034461
# abalone             0.952401   0.00682
# whole_mean           0.95095  0.021639
# precision
#               MTSBag           SMOTEMTSBag           MTSBagImpAgg            \
#                 mean       std        mean       std         mean       std
# car         0.437885  0.071538    0.369134  0.074066     0.496448  0.071259
# cancer      0.900294  0.045701    0.854506  0.044906     0.905062  0.027487
# letter      0.888112  0.031176    0.521589  0.069883     0.897575  0.053323
# wine        0.915023  0.084797    0.925868  0.071249     0.929916  0.067577
# abalone     0.402149  0.076598     0.24009  0.045181     0.403859  0.085603
# whole_mean  0.708693  0.061962    0.582237  0.061057     0.726572   0.06105
#
#            SMOTEMTSBagImpAgg
#                         mean       std
# car                 0.435323  0.093148
# cancer              0.857559  0.064824
# letter              0.561998  0.076141
# wine                0.927639  0.079156
# abalone             0.235646  0.067653
# whole_mean          0.603633  0.076184
# gmeans
#               MTSBag           SMOTEMTSBag           MTSBagImpAgg            \
#                 mean       std        mean       std         mean       std
# car         0.946304  0.049857    0.883631  0.100571     0.968263  0.026207
# cancer      0.959706  0.015725    0.946257  0.023342     0.960624  0.014931
# letter       0.81571  0.040882    0.900468  0.010917     0.815143  0.033134
# wine        0.965483  0.025068    0.957464  0.058885     0.957338  0.051453
# abalone     0.919631  0.066591    0.961171  0.017619     0.911007  0.045052
# whole_mean  0.921367  0.039625    0.929798  0.042267     0.922475  0.034156
#
#            SMOTEMTSBagImpAgg
#                         mean       std
# car                 0.923302  0.041809
# cancer              0.947117  0.020589
# letter              0.901322  0.025923
# wine                0.970445  0.023528
# abalone             0.956049  0.019659
# whole_mean          0.939647  0.026302
# RS
#               MTSBag           SMOTEMTSBag           MTSBagImpAgg            \
#                 mean       std        mean       std         mean       std
# car         0.992003  0.106188    0.897791  0.205755     1.028764  0.064842
# cancer      1.042705  0.059328    1.083123  0.061477      1.02625  0.034036
# letter      0.671288  0.065824     0.86609  0.023423     0.669886  0.055497
# wine        1.012185  0.079492    0.969898  0.103564      0.96923  0.078565
# abalone     0.882564  0.126386    1.023683  0.038665     0.870329   0.08818
# whole_mean  0.920149  0.087443    0.968117  0.086577     0.912892  0.064224
#
#            SMOTEMTSBagImpAgg
#                         mean       std
# car                 0.956819  0.102058
# cancer              1.072458  0.072752
# letter              0.863095  0.069674
# wine                1.005072  0.067908
# abalone             1.008575  0.052484
# whole_mean          0.981204  0.072975
