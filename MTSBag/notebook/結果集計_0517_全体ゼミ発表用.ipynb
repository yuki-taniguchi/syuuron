# %% [markdown]
# # 分析結果を集計するノートブック
# - 一旦AUCだけで比較してみる
# - output/ファイルから各手法の各データの結果をまとめる
# - それらの平均をまとめる
# - 分散分析とかグラフとかにして表示する

# %%
from glob import glob

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
ex_name = '0514'

# %%
file_list = glob(f'../data/output/{ex_name}*')

# %%
e_index = ['AUC', 'accuracy', 'recall', 'Specificity', 'precision', 'gmeans', 'RS']

method = list(set([file.split('\\')[1].split('_')[1] for file in file_list]))
method = list(set(method)- set(e_index))
method = ['MTS', 'MTSBag', 'MTSBagImpAgg']
method
# Out:
# ['MTS', 'MTSBag', 'MTSBagImpAgg']

# %%
data = list(set([file.split('\\')[1].split('_')[2] for file in file_list]))
data = ['car', 'cancer', 'letter', 'wine', 'abalone',
#  'yeast'
 ]
data
# Out:
# ['car', 'cancer', 'letter', 'wine', 'abalone']

# %%
e_index = ['AUC', 'accuracy', 'recall', 'Specificity', 'precision', 'gmeans', 'RS']
multi_columns = [
    np.array(
        [method[0]] * 2 + 
        [method[1]] * 2 + 
        [method[2]] * 2 
        # + 
        # [method[3]] * 2 
        # +
        # [method[4]] * 2 +
        # [method[5]] * 2 
        # +
        # [method[6]] * 2 
        # +
        # [method[7]] * 2 +
        # [method[8]] * 2 
        ),
    np.array(["mean", "std"] * len(method))
]

# %%
for e in e_index:
    index_result_df = pd.DataFrame(
                index=data,
                columns=multi_columns,
                )
    for m in method:
        for d in data:     
            df = pd.read_csv(f'../data/output/{ex_name}_{m}_{d}_result.csv', index_col=0)
            index_result_df.loc[d, m] = [df[e].mean(), df[e].std()]
    index_result_df.loc['whole_mean'] = index_result_df.mean(axis=0)
    print(e)
    display(index_result_df)
    index_result_df.to_csv(f'../data/output/{ex_name}_{e}_score.csv')
    a = index_result_df.T[index_result_df.T.index.get_level_values(1) == 'mean']
    a = a.reset_index(level=1).drop('level_1', axis=1)
    a.T.to_csv(f'../data/output/{ex_name}_{e}_score_mean.csv')
    sns.heatmap(a.T.astype(float), annot=True, fmt='.4', cmap='coolwarm', vmin=0.9000, vmax=1.0000)
    plt.show()
# Out:
# AUC
#                  MTS              MTSBag           MTSBagImpAgg
#                 mean       std      mean       std         mean       std
# car         0.973099  0.008034  0.975745  0.008677     0.981977  0.012011
# cancer      0.946351  0.062023  0.987332  0.007582     0.985934  0.006054
# letter      0.918355  0.033662  0.924265  0.014372     0.973235  0.008335
# wine        0.992137  0.010902  0.995605  0.006846     0.995494  0.005927
# abalone     0.986174   0.00169  0.953121  0.044746     0.986433  0.005242
# whole_mean  0.963223  0.023262  0.967213  0.016445     0.984615  0.007514
# accuracy
#                  MTS              MTSBag           MTSBagImpAgg
#                 mean       std      mean       std         mean       std
# car          0.95289  0.008293  0.950867  0.008617     0.956358  0.009483
# cancer      0.912857  0.066904  0.954286  0.015865     0.956429    0.0128
# letter      0.966825  0.009714    0.9843  0.002723       0.9838  0.002044
# wine        0.941667  0.044309  0.963889  0.026352     0.966667  0.034146
# abalone      0.97488  0.004066  0.979665   0.00465     0.975598  0.003791
# whole_mean  0.949824  0.026657  0.966601  0.011641      0.96777  0.012453
# recall
#                  MTS              MTSBag           MTSBagImpAgg
#                 mean       std      mean       std         mean       std
# car         0.921968  0.103506  0.943651   0.09788     0.982353  0.055805
# cancer      0.916261  0.061407  0.979658   0.03349     0.973155  0.027439
# letter      0.568099  0.039406  0.669084  0.065763     0.667662  0.054739
# wine        0.928052  0.141489  0.970833  0.048947     0.943409  0.084567
# abalone     0.853328  0.078024  0.865973  0.123373     0.850819  0.084798
# whole_mean  0.837542  0.084766   0.88584  0.073891      0.88348   0.06147
# Specificity
#                  MTS              MTSBag           MTSBagImpAgg
#                 mean       std      mean       std         mean       std
# car         0.954028   0.00943  0.951604  0.008953     0.955316  0.011312
# cancer      0.909907  0.081054  0.940884  0.030145      0.94849  0.014285
# letter      0.982714  0.009894    0.9967  0.000933     0.996748  0.001943
# wine        0.948938  0.057259  0.961504  0.040596     0.972998  0.026063
# abalone      0.97722  0.005075  0.981312  0.004548     0.977718  0.004238
# whole_mean  0.954561  0.032542  0.966401  0.017035     0.970254  0.011568
# precision
#                  MTS              MTSBag           MTSBagImpAgg
#                 mean       std      mean       std         mean       std
# car         0.444819  0.103713  0.437885  0.071538     0.496448  0.071259
# cancer      0.848417  0.105601  0.900294  0.045701     0.905062  0.027487
# letter      0.598192  0.149667  0.888112  0.031176     0.897575  0.053323
# wine        0.840606  0.174109  0.915023  0.084797     0.929916  0.067577
# abalone       0.4145  0.062624  0.402149  0.076598     0.403859  0.085603
# whole_mean  0.629307  0.119143  0.708693  0.061962     0.726572   0.06105
# gmeans
#                  MTS              MTSBag           MTSBagImpAgg
#                 mean       std      mean       std         mean       std
# car         0.936423  0.052749  0.946304  0.049857     0.968263  0.026207
# cancer      0.912464  0.063821  0.959706  0.015725     0.960624  0.014931
# letter      0.746774  0.026296   0.81571  0.040882     0.815143  0.033134
# wine        0.934191  0.071804  0.965483  0.025068     0.957338  0.051453
# abalone     0.912221  0.040672  0.919631  0.066591     0.911007  0.045052
# whole_mean  0.888415  0.051068  0.921367  0.039625     0.922475  0.034156
# RS
#                  MTS              MTSBag           MTSBagImpAgg
#                 mean       std      mean       std         mean       std
# car         0.966687  0.111116  0.992003  0.106188     1.028764  0.064842
# cancer      1.011886  0.082217  1.042705  0.059328      1.02625  0.034036
# letter      0.578129  0.040111  0.671288  0.065824     0.669886  0.055497
# wine         0.98531  0.182802  1.012185  0.079492      0.96923  0.078565
# abalone     0.873506  0.082955  0.882564  0.126386     0.870329   0.08818
# whole_mean  0.883104   0.09984  0.920149  0.087443     0.912892  0.064224
