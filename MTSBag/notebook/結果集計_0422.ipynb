# %% [markdown]
# # 分析結果を集計するノートブック
# - 一旦AUCだけで比較してみる
# - output/ファイルから各手法の各データの結果をまとめる
# - それらの平均をまとめる
# - 分散分析とかグラフとかにして表示する

# %%
import pandas as pd
import numpy as np

# %%
ex_name = '0422'

# %%
method = ['MTS', 'MTS2', 'WMTS', 'MTSBag', 'MTSBagImpAgg', 'SMOTEMTSBag', 'SMOTEMTSBagImpAgg', 'WMTSBagImpAgg',
#  'LGBM', 'RUSB', 'SVM'
 ]
data = ['abalone', 'cancer', 'car', 'letter', 'wine', 
'yeast'
]
e_index = ['AUC', 'accuracy', 'recall', 'Specificity', 'precision', 'gmeans', 'RS']

multi_m_list = []
for m in method:
    multi_m_list += [m]*2

multi_columns = [
    np.array(multi_m_list),
    np.array(["mean", "std"] * len(method))
]

# %%
import seaborn as sns

# %%
a = index_result_df.T[index_result_df.T.index.get_level_values(1) == 'mean']
a = a.reset_index(level=1).drop('level_1', axis=1)

# %%
a
# Out:
#                     abalone    cancer       car    letter      wine     yeast  \
# MTS                0.809381   0.93788  0.990285   0.56348  0.908774  0.367719
# MTS2               0.906793  1.037582  0.967982  0.579655  1.032115  0.300192
# WMTS               0.861871  1.028005  1.058932  0.625408  1.010952  0.352568
# MTSBag             0.824698  1.001317  0.985099  0.643207  1.033847  0.282356
# MTSBagImpAgg       0.902943  1.016696   1.04864  0.649133  0.985137   0.27823
# SMOTEMTSBag        0.905879  0.902477  0.904474  0.895822    0.9265  0.903201
# SMOTEMTSBagImpAgg  0.861721    0.8573  0.872379  0.857003   0.87039  0.866684
# WMTSBagImpAgg      0.887288  1.070763  0.977091  0.636648  1.037721  0.298334
#
#                   whole_mean
# MTS                  0.76292
# MTS2                0.804053
# WMTS                0.822956
# MTSBag              0.795087
# MTSBagImpAgg        0.813463
# SMOTEMTSBag         0.906392
# SMOTEMTSBagImpAgg   0.864246
# WMTSBagImpAgg       0.817974

# %%
for e in e_index:
    index_result_df = pd.DataFrame(
                index=data,
                columns=multi_columns,
                )
    for m in method:
        for d in data:     
            df = pd.read_csv(f'../data/output/{ex_name}_{m}_{d}_result.csv', index_col=0)
            index_result_df.loc[d, m] = [df[e].mean(), df[e].std()]
    index_result_df.loc['whole_mean'] = index_result_df.mean(axis=0)
    print(e)
    display(index_result_df)
    index_result_df.to_csv(f'../data/output/{ex_name}_{e}_score.csv')
# Out:
# AUC
#                  MTS                MTS2                WMTS            \
#                 mean       std      mean       std      mean       std
# abalone     0.987433  0.003274  0.987549  0.004072  0.986822  0.002466
# cancer      0.940135  0.053196  0.943072  0.051562  0.963802  0.019364
# car         0.971084   0.00702  0.970117  0.007778  0.959037  0.012694
# letter      0.916527  0.037723  0.919691  0.031037  0.918394  0.038003
# wine        0.990659   0.00822  0.996322  0.004916  0.991795  0.011785
# yeast       0.728986  0.057904  0.653609  0.096344  0.742995  0.082926
# whole_mean  0.922471   0.02789  0.911727  0.032618  0.927141  0.027873
#
#               MTSBag           MTSBagImpAgg           SMOTEMTSBag            \
#                 mean       std         mean       std        mean       std
# abalone     0.965561  0.028744     0.987025  0.003769    0.965754  0.009494
# cancer      0.984301  0.007077     0.978781  0.011322    0.966418  0.010217
# car          0.97761  0.010565     0.982491  0.005969    0.965786  0.009441
# letter      0.922463  0.011195        0.973  0.007382     0.96423  0.008497
# wine        0.994656  0.006018     0.998319  0.004001    0.968734  0.007438
# yeast       0.728883  0.100504     0.791655  0.061325    0.962324  0.010657
# whole_mean  0.928912  0.027351     0.951879  0.015628    0.965541  0.009291
#
#            SMOTEMTSBagImpAgg           WMTSBagImpAgg
#                         mean       std          mean       std
# abalone             0.972555   0.00386      0.988434   0.00251
# cancer              0.970487  0.006659      0.973471  0.015396
# car                  0.97176  0.005052      0.964825  0.012058
# letter              0.971644  0.004839       0.96106  0.013386
# wine                0.963273  0.008749       0.98869  0.018616
# yeast                0.97051  0.004077      0.798665   0.07935
# whole_mean          0.970038  0.005539      0.945857  0.023553
# accuracy
#                  MTS                MTS2                WMTS            \
#                 mean       std      mean       std      mean       std
# abalone     0.977512  0.004909  0.976555  0.007756  0.977273  0.005075
# cancer      0.916429  0.042063  0.907143  0.044671  0.917143  0.022638
# car         0.948844  0.009735  0.951734  0.008293  0.927457  0.018901
# letter       0.96715  0.008626  0.966125  0.011483   0.95595  0.021069
# wine        0.944444   0.02928  0.961111   0.02986  0.952778  0.039393
# yeast       0.914478  0.068696  0.917508  0.040381  0.914141  0.038102
# whole_mean   0.94481  0.027218  0.946696  0.023741   0.94079  0.024196
#
#               MTSBag           MTSBagImpAgg           SMOTEMTSBag            \
#                 mean       std         mean       std        mean       std
# abalone     0.977871  0.006678     0.976196   0.00673    0.962825  0.007354
# cancer      0.953571  0.018519     0.952143  0.022348     0.96005  0.010343
# car         0.956647  0.011561     0.955491  0.009058      0.9615  0.011293
# letter      0.982925  0.003197       0.9828  0.001989       0.964  0.010746
# wine        0.952778  0.026352     0.977778  0.021911    0.948975  0.027753
# yeast       0.935354  0.012678     0.945118  0.015797        0.96  0.011268
# whole_mean  0.959858  0.013164     0.964921  0.012972    0.959558  0.013126
#
#            SMOTEMTSBagImpAgg           WMTSBagImpAgg
#                         mean       std          mean       std
# abalone               0.9679  0.005537      0.977871  0.005083
# cancer              0.966025  0.010228      0.925714  0.035025
# car                   0.9595  0.011353      0.931214  0.016675
# letter              0.966425  0.009042         0.978  0.004243
# wine                  0.9536  0.011392          0.95  0.028689
# yeast                 0.9639  0.006792      0.938721    0.0173
# whole_mean          0.962892  0.009057      0.950253  0.017836
# recall
#                  MTS                MTS2                WMTS            \
#                 mean       std      mean       std      mean       std
# abalone     0.793471   0.13098  0.886965  0.078916   0.84399  0.106184
# cancer      0.875172  0.133267  0.925763  0.045379   0.93234  0.042348
# car         0.938929  0.105388  0.921882   0.11061  0.978974  0.033969
# letter      0.554331   0.04055  0.569454  0.034348  0.607269  0.063776
# wine        0.881402  0.122351  0.981746  0.039603  0.961111  0.064417
# yeast        0.33197  0.203801  0.273737  0.217983  0.320498  0.196706
# whole_mean  0.729212  0.122723  0.759925  0.087807   0.77403  0.084567
#
#               MTSBag           MTSBagImpAgg           SMOTEMTSBag            \
#                 mean       std         mean       std        mean       std
# abalone      0.80835  0.117265     0.882991  0.083978    0.875325  0.016427
# cancer      0.955356  0.040268     0.961701   0.02886    0.869481  0.022379
# car         0.943302  0.090667          1.0       0.0    0.872727  0.018161
# letter      0.641522    0.0674     0.646955   0.04726    0.866883  0.020131
# wine        0.975641   0.03926     0.967298  0.053272    0.880519  0.024906
# yeast       0.270861  0.113806     0.266991  0.154186     0.87013   0.01811
# whole_mean  0.765839  0.078111     0.787656   0.06126    0.872511  0.020019
#
#            SMOTEMTSBagImpAgg           WMTSBagImpAgg
#                         mean       std          mean       std
# abalone             0.838462  0.021749      0.869579  0.091364
# cancer              0.832692  0.014633      0.965078   0.03393
# car                 0.841026  0.024325      0.908292  0.169126
# letter              0.832692  0.016946      0.631586  0.091967
# wine                0.833974  0.019919      0.976923  0.051919
# yeast               0.839744  0.016825      0.286339  0.111099
# whole_mean          0.836432  0.019066      0.772966  0.091567
# Specificity
#                  MTS                MTS2                WMTS            \
#                 mean       std      mean       std      mean       std
# abalone     0.980859    0.0058  0.978194  0.007769  0.979664  0.005808
# cancer      0.934377  0.025902  0.897335  0.067015  0.909651  0.041061
# car         0.948812  0.011537  0.952658  0.008487  0.925331  0.020699
# letter      0.983607  0.008729  0.982139  0.011178   0.97052   0.02076
# wine        0.972817  0.025302  0.953494  0.043531  0.954249  0.049817
# yeast       0.935092  0.073575  0.940789  0.048264  0.934491  0.045336
# whole_mean  0.959261  0.025141  0.950768   0.03104  0.945651   0.03058
#
#               MTSBag           MTSBagImpAgg           SMOTEMTSBag            \
#                 mean       std         mean       std        mean       std
# abalone     0.980552  0.007096     0.977832   0.00635    0.966329  0.007633
# cancer      0.954104  0.013239     0.947327  0.034947    0.963677  0.011149
# car         0.957246  0.009589     0.953699   0.00941    0.965055  0.011802
# letter      0.997395  0.001523     0.996693  0.001531    0.967889  0.011393
# wine        0.945227  0.036032     0.981949  0.019092    0.951716  0.029486
# yeast       0.961571  0.015254     0.967996  0.018712    0.963599  0.011962
# whole_mean  0.966016  0.013789     0.970916  0.015007    0.963044  0.013904
#
#            SMOTEMTSBagImpAgg           WMTSBagImpAgg
#                         mean       std          mean       std
# abalone             0.973153   0.00637       0.98011  0.005044
# cancer              0.971436  0.010738        0.9055  0.057372
# car                 0.964308  0.012118      0.933476  0.025097
# letter              0.971852   0.00989      0.992549  0.005681
# wine                0.958455  0.012298      0.943548  0.038637
# yeast               0.968939  0.006917      0.962316  0.017815
# whole_mean          0.968024  0.009722      0.952916  0.024941
# precision
#                  MTS                MTS2                WMTS            \
#                 mean       std      mean       std      mean       std
# abalone     0.445572  0.079223  0.439133  0.090595  0.418388   0.10158
# cancer       0.86872   0.04778  0.828608  0.087176  0.846413  0.055648
# car         0.430067    0.0747  0.456202  0.068259  0.360793  0.069405
# letter      0.599098   0.14863  0.599427  0.175058  0.525611  0.210292
# wine        0.935079  0.065988  0.898808  0.090757  0.864307  0.146337
# yeast       0.216936  0.139026  0.124936  0.085091  0.158541  0.075048
# whole_mean  0.582579  0.092558  0.557852  0.099489  0.529009  0.109718
#
#               MTSBag           MTSBagImpAgg           SMOTEMTSBag            \
#                 mean       std         mean       std        mean       std
# abalone     0.408296  0.090531     0.425991  0.103919    0.515689  0.057997
# cancer      0.909028  0.044016     0.904599  0.054777    0.500066  0.074583
# car         0.482611  0.087802      0.46796  0.067803    0.511797  0.077528
# letter      0.913709  0.050261     0.893114  0.041617    0.534202  0.096947
# wine        0.879872  0.095776     0.940631  0.065631    0.463629  0.138174
# yeast       0.221762  0.083649     0.226053  0.107099    0.502084  0.085596
# whole_mean   0.63588  0.075339     0.643058  0.073474    0.504578  0.088471
#
#            SMOTEMTSBagImpAgg           WMTSBagImpAgg
#                         mean       std          mean       std
# abalone             0.564663  0.055306      0.466001  0.067469
# cancer              0.556161  0.092952      0.851854  0.079985
# car                 0.501081  0.078315      0.375022  0.165974
# letter              0.561136  0.105648      0.802278  0.103868
# wine                0.459988   0.07339      0.863397  0.094754
# yeast               0.527888  0.050845      0.231542  0.105446
# whole_mean          0.528486  0.076076      0.598349  0.102916
# gmeans
#                  MTS                MTS2                WMTS            \
#                 mean       std      mean       std      mean       std
# abalone     0.879318  0.072244  0.930611  0.041917  0.907601  0.055426
# cancer      0.901175  0.075629  0.910555  0.040369  0.920259  0.020127
# car         0.942253  0.052737  0.935463  0.057268  0.951481  0.012697
# letter      0.737998  0.028413   0.74761  0.025298   0.76686  0.045098
# wine        0.923275   0.05712  0.966989  0.025493   0.95661  0.034641
# yeast       0.507392  0.222169  0.412723  0.297713   0.52009  0.154847
# whole_mean  0.815235  0.084719  0.817325  0.081343   0.83715  0.053806
#
#               MTSBag           MTSBagImpAgg           SMOTEMTSBag            \
#                 mean       std         mean       std        mean       std
# abalone     0.887729  0.069135     0.928279  0.044869    0.919658  0.009343
# cancer      0.954558  0.023078     0.954184  0.019915    0.915258  0.010318
# car          0.94928  0.049745     0.976565  0.004808    0.917665  0.010504
# letter      0.798847  0.043283     0.802505  0.029282    0.915907   0.01047
# wine          0.9599  0.023318     0.974283  0.031222    0.915127   0.01193
# yeast       0.498998  0.109992     0.491022  0.130192    0.915592  0.009187
# whole_mean  0.841552  0.053092     0.854473  0.043381    0.916534  0.010292
#
#            SMOTEMTSBagImpAgg           WMTSBagImpAgg
#                         mean       std          mean       std
# abalone             0.903201  0.009899      0.922028  0.048405
# cancer              0.899342  0.008552      0.934069  0.028802
# car                 0.900432  0.012366      0.915288  0.087927
# letter              0.899504    0.0066      0.789632  0.058352
# wine                0.893941  0.008779      0.959417   0.02707
# yeast                0.90199  0.010094      0.515046  0.103484
# whole_mean          0.899735  0.009382      0.839246  0.059007
# RS
#                  MTS                MTS2                WMTS            \
#                 mean       std      mean       std      mean       std
# abalone     0.809381  0.136441  0.906793  0.081088  0.861871   0.11145
# cancer       0.93788  0.149348  1.037582  0.104796  1.028005  0.085016
# car         0.990285  0.116387  0.967982  0.118457  1.058932  0.054846
# letter       0.56348  0.039563  0.579655  0.031223  0.625408  0.061127
# wine        0.908774  0.143734  1.032115  0.072154  1.010952  0.100885
# yeast       0.367719  0.238592  0.300192  0.242356  0.352568  0.233903
# whole_mean   0.76292  0.137344  0.804053  0.108346  0.822956  0.107871
#
#               MTSBag           MTSBagImpAgg           SMOTEMTSBag            \
#                 mean       std         mean       std        mean       std
# abalone     0.824698  0.121665     0.902943   0.08472    0.905879  0.018649
# cancer      1.001317  0.039994     1.016696  0.054613    0.902477  0.029727
# car         0.985099  0.090873      1.04864  0.010263    0.904474  0.022887
# letter      0.643207  0.067765     0.649133  0.047865    0.895822  0.026014
# wine        1.033847  0.063112     0.985137  0.052426      0.9265  0.050924
# yeast       0.282356  0.119806      0.27823   0.16823    0.903201  0.025078
# whole_mean  0.795087  0.083869     0.813463  0.069686    0.906392   0.02888
#
#            SMOTEMTSBagImpAgg           WMTSBagImpAgg
#                         mean       std          mean       std
# abalone             0.861721  0.026638      0.887288  0.094046
# cancer                0.8573  0.019314      1.070763  0.093784
# car                 0.872379  0.030839      0.977091  0.194768
# letter              0.857003  0.024446      0.636648  0.094903
# wine                 0.87039  0.028628      1.037721  0.081125
# yeast               0.866684  0.017347      0.298334  0.117393
# whole_mean          0.864246  0.024536      0.817974   0.11267
