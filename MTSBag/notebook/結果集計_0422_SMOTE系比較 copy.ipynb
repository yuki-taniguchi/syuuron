# %% [markdown]
# # 分析結果を集計するノートブック
# - 一旦AUCだけで比較してみる
# - output/ファイルから各手法の各データの結果をまとめる
# - それらの平均をまとめる
# - 分散分析とかグラフとかにして表示する

# %%
import pandas as pd
import numpy as np

# %%
ex_name = '0422'

# %%
method = ['MTS', 'MTSBag', 'MTSBagImpAgg', 'SMOTEMTSBag', 'SMOTEMTSBagImpAgg']
data = ['abalone', 'cancer', 'car', 'letter', 'wine', 
'yeast'
]
e_index = ['AUC', 'accuracy', 'recall', 'Specificity', 'precision', 'gmeans', 'RS']

multi_m_list = []
for m in method:
    multi_m_list += [m]*2

multi_columns = [
    np.array(multi_m_list),
    np.array(["mean", "std"] * len(method))
]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
for e in e_index:
    index_result_df = pd.DataFrame(
                index=data,
                columns=multi_columns,
                )
    for m in method:
        for d in data:     
            df = pd.read_csv(f'../data/output/{ex_name}_{m}_{d}_result.csv', index_col=0)
            index_result_df.loc[d, m] = [df[e].mean(), df[e].std()]
    index_result_df.loc['whole_mean'] = index_result_df.mean(axis=0)
    print(e)
    display(index_result_df)
    a = index_result_df.T[index_result_df.T.index.get_level_values(1) == 'mean']
    a = a.reset_index(level=1).drop('level_1', axis=1)
    sns.heatmap(a.T.astype(float), annot=True)
    plt.show()
    index_result_df.to_csv(f'../data/output/{ex_name}_{e}_score.csv')
# Out:
# AUC
#                  MTS              MTSBag           MTSBagImpAgg            \
#                 mean       std      mean       std         mean       std
# abalone     0.987433  0.003274  0.965561  0.028744     0.987025  0.003769
# cancer      0.940135  0.053196  0.984301  0.007077     0.978781  0.011322
# car         0.971084   0.00702   0.97761  0.010565     0.982491  0.005969
# letter      0.916527  0.037723  0.922463  0.011195        0.973  0.007382
# wine        0.990659   0.00822  0.994656  0.006018     0.998319  0.004001
# yeast       0.728986  0.057904  0.728883  0.100504     0.791655  0.061325
# whole_mean  0.922471   0.02789  0.928912  0.027351     0.951879  0.015628
#
#            SMOTEMTSBag           SMOTEMTSBagImpAgg
#                   mean       std              mean       std
# abalone       0.965754  0.009494          0.972555   0.00386
# cancer        0.966418  0.010217          0.970487  0.006659
# car           0.965786  0.009441           0.97176  0.005052
# letter         0.96423  0.008497          0.971644  0.004839
# wine          0.968734  0.007438          0.963273  0.008749
# yeast         0.962324  0.010657           0.97051  0.004077
# whole_mean    0.965541  0.009291          0.970038  0.005539
# accuracy
#                  MTS              MTSBag           MTSBagImpAgg            \
#                 mean       std      mean       std         mean       std
# abalone     0.977512  0.004909  0.977871  0.006678     0.976196   0.00673
# cancer      0.916429  0.042063  0.953571  0.018519     0.952143  0.022348
# car         0.948844  0.009735  0.956647  0.011561     0.955491  0.009058
# letter       0.96715  0.008626  0.982925  0.003197       0.9828  0.001989
# wine        0.944444   0.02928  0.952778  0.026352     0.977778  0.021911
# yeast       0.914478  0.068696  0.935354  0.012678     0.945118  0.015797
# whole_mean   0.94481  0.027218  0.959858  0.013164     0.964921  0.012972
#
#            SMOTEMTSBag           SMOTEMTSBagImpAgg
#                   mean       std              mean       std
# abalone       0.962825  0.007354            0.9679  0.005537
# cancer         0.96005  0.010343          0.966025  0.010228
# car             0.9615  0.011293            0.9595  0.011353
# letter           0.964  0.010746          0.966425  0.009042
# wine          0.948975  0.027753            0.9536  0.011392
# yeast             0.96  0.011268            0.9639  0.006792
# whole_mean    0.959558  0.013126          0.962892  0.009057
# recall
#                  MTS              MTSBag           MTSBagImpAgg            \
#                 mean       std      mean       std         mean       std
# abalone     0.793471   0.13098   0.80835  0.117265     0.882991  0.083978
# cancer      0.875172  0.133267  0.955356  0.040268     0.961701   0.02886
# car         0.938929  0.105388  0.943302  0.090667          1.0       0.0
# letter      0.554331   0.04055  0.641522    0.0674     0.646955   0.04726
# wine        0.881402  0.122351  0.975641   0.03926     0.967298  0.053272
# yeast        0.33197  0.203801  0.270861  0.113806     0.266991  0.154186
# whole_mean  0.729212  0.122723  0.765839  0.078111     0.787656   0.06126
#
#            SMOTEMTSBag           SMOTEMTSBagImpAgg
#                   mean       std              mean       std
# abalone       0.875325  0.016427          0.838462  0.021749
# cancer        0.869481  0.022379          0.832692  0.014633
# car           0.872727  0.018161          0.841026  0.024325
# letter        0.866883  0.020131          0.832692  0.016946
# wine          0.880519  0.024906          0.833974  0.019919
# yeast          0.87013   0.01811          0.839744  0.016825
# whole_mean    0.872511  0.020019          0.836432  0.019066
# Specificity
#                  MTS              MTSBag           MTSBagImpAgg            \
#                 mean       std      mean       std         mean       std
# abalone     0.980859    0.0058  0.980552  0.007096     0.977832   0.00635
# cancer      0.934377  0.025902  0.954104  0.013239     0.947327  0.034947
# car         0.948812  0.011537  0.957246  0.009589     0.953699   0.00941
# letter      0.983607  0.008729  0.997395  0.001523     0.996693  0.001531
# wine        0.972817  0.025302  0.945227  0.036032     0.981949  0.019092
# yeast       0.935092  0.073575  0.961571  0.015254     0.967996  0.018712
# whole_mean  0.959261  0.025141  0.966016  0.013789     0.970916  0.015007
#
#            SMOTEMTSBag           SMOTEMTSBagImpAgg
#                   mean       std              mean       std
# abalone       0.966329  0.007633          0.973153   0.00637
# cancer        0.963677  0.011149          0.971436  0.010738
# car           0.965055  0.011802          0.964308  0.012118
# letter        0.967889  0.011393          0.971852   0.00989
# wine          0.951716  0.029486          0.958455  0.012298
# yeast         0.963599  0.011962          0.968939  0.006917
# whole_mean    0.963044  0.013904          0.968024  0.009722
# precision
#                  MTS              MTSBag           MTSBagImpAgg            \
#                 mean       std      mean       std         mean       std
# abalone     0.445572  0.079223  0.408296  0.090531     0.425991  0.103919
# cancer       0.86872   0.04778  0.909028  0.044016     0.904599  0.054777
# car         0.430067    0.0747  0.482611  0.087802      0.46796  0.067803
# letter      0.599098   0.14863  0.913709  0.050261     0.893114  0.041617
# wine        0.935079  0.065988  0.879872  0.095776     0.940631  0.065631
# yeast       0.216936  0.139026  0.221762  0.083649     0.226053  0.107099
# whole_mean  0.582579  0.092558   0.63588  0.075339     0.643058  0.073474
#
#            SMOTEMTSBag           SMOTEMTSBagImpAgg
#                   mean       std              mean       std
# abalone       0.515689  0.057997          0.564663  0.055306
# cancer        0.500066  0.074583          0.556161  0.092952
# car           0.511797  0.077528          0.501081  0.078315
# letter        0.534202  0.096947          0.561136  0.105648
# wine          0.463629  0.138174          0.459988   0.07339
# yeast         0.502084  0.085596          0.527888  0.050845
# whole_mean    0.504578  0.088471          0.528486  0.076076
# gmeans
#                  MTS              MTSBag           MTSBagImpAgg            \
#                 mean       std      mean       std         mean       std
# abalone     0.879318  0.072244  0.887729  0.069135     0.928279  0.044869
# cancer      0.901175  0.075629  0.954558  0.023078     0.954184  0.019915
# car         0.942253  0.052737   0.94928  0.049745     0.976565  0.004808
# letter      0.737998  0.028413  0.798847  0.043283     0.802505  0.029282
# wine        0.923275   0.05712    0.9599  0.023318     0.974283  0.031222
# yeast       0.507392  0.222169  0.498998  0.109992     0.491022  0.130192
# whole_mean  0.815235  0.084719  0.841552  0.053092     0.854473  0.043381
#
#            SMOTEMTSBag           SMOTEMTSBagImpAgg
#                   mean       std              mean       std
# abalone       0.919658  0.009343          0.903201  0.009899
# cancer        0.915258  0.010318          0.899342  0.008552
# car           0.917665  0.010504          0.900432  0.012366
# letter        0.915907   0.01047          0.899504    0.0066
# wine          0.915127   0.01193          0.893941  0.008779
# yeast         0.915592  0.009187           0.90199  0.010094
# whole_mean    0.916534  0.010292          0.899735  0.009382
# RS
#                  MTS              MTSBag           MTSBagImpAgg            \
#                 mean       std      mean       std         mean       std
# abalone     0.809381  0.136441  0.824698  0.121665     0.902943   0.08472
# cancer       0.93788  0.149348  1.001317  0.039994     1.016696  0.054613
# car         0.990285  0.116387  0.985099  0.090873      1.04864  0.010263
# letter       0.56348  0.039563  0.643207  0.067765     0.649133  0.047865
# wine        0.908774  0.143734  1.033847  0.063112     0.985137  0.052426
# yeast       0.367719  0.238592  0.282356  0.119806      0.27823   0.16823
# whole_mean   0.76292  0.137344  0.795087  0.083869     0.813463  0.069686
#
#            SMOTEMTSBag           SMOTEMTSBagImpAgg
#                   mean       std              mean       std
# abalone       0.905879  0.018649          0.861721  0.026638
# cancer        0.902477  0.029727            0.8573  0.019314
# car           0.904474  0.022887          0.872379  0.030839
# letter        0.895822  0.026014          0.857003  0.024446
# wine            0.9265  0.050924           0.87039  0.028628
# yeast         0.903201  0.025078          0.866684  0.017347
# whole_mean    0.906392   0.02888          0.864246  0.024536
